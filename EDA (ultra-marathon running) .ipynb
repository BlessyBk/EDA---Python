# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df=pd.read_csv("/Users/blessybabu/Downloads/archive (2)/TWO_CENTURIES_OF_UM_RACES.csv")
# Out:
# /var/folders/rc/tjd3sybx64z78y7cpl6g_7kh0000gn/T/ipykernel_45851/2584755153.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("/Users/blessybabu/Downloads/archive (2)/TWO_CENTURIES_OF_UM_RACES.csv")

# %%
df.head(10)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
# 5           2018  06.01.2018  Selva Costera (CHI)                  50km
# 6           2018  06.01.2018  Selva Costera (CHI)                  50km
# 7           2018  06.01.2018  Selva Costera (CHI)                  50km
# 8           2018  06.01.2018  Selva Costera (CHI)                  50km
# 9           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                         22           4:51:39 h                Tnfrc
# ...

# %%
df.shape
# Out:
# (7461195, 13)

# %%
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
df[df['Event distance/length']=='50km']
# Out:
#          Year of event Event dates                             Event name  \
# 0                 2018  06.01.2018                    Selva Costera (CHI)
# 1                 2018  06.01.2018                    Selva Costera (CHI)
# 2                 2018  06.01.2018                    Selva Costera (CHI)
# 3                 2018  06.01.2018                    Selva Costera (CHI)
# 4                 2018  06.01.2018                    Selva Costera (CHI)
# ...                ...         ...                                    ...
# 7461089           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461090           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461091           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461092           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461093           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
df[df['Event distance/length'].isin(['50km','50mi'])]
# Out:
#          Year of event Event dates                        Event name  \
# 0                 2018  06.01.2018               Selva Costera (CHI)
# 1                 2018  06.01.2018               Selva Costera (CHI)
# 2                 2018  06.01.2018               Selva Costera (CHI)
# 3                 2018  06.01.2018               Selva Costera (CHI)
# 4                 2018  06.01.2018               Selva Costera (CHI)
# ...                ...         ...                               ...
# 7461181           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461182           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461183           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461184           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461185           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event']==2020)]
# Out:
#          Year of event     Event dates  \
# 2538571           2020  07.-09.02.2020
# 2538572           2020  07.-09.02.2020
# 2538573           2020  07.-09.02.2020
# 2538574           2020  07.-09.02.2020
# 2538575           2020  07.-09.02.2020
# ...                ...             ...
# 2762404           2020      03.10.2020
# 2762405           2020      03.10.2020
# 2762406           2020      03.10.2020
# 2762407           2020      03.10.2020
# 2762408           2020      03.10.2020
#
#                                       Event name Event distance/length  \
# 2538571  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538572  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538573  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538574  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538575  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# ...

# %%
df[df['Event name'] == 'Everglades 50 Mile Ultra Run (USA)']
# Out:
#          Year of event Event dates                          Event name  \
# 51923             2018  17.02.2018  Everglades 50 Mile Ultra Run (USA)
# 51924             2018  17.02.2018  Everglades 50 Mile Ultra Run (USA)
# 51925             2018  17.02.2018  Everglades 50 Mile Ultra Run (USA)
# 51926             2018  17.02.2018  Everglades 50 Mile Ultra Run (USA)
# 51927             2018  17.02.2018  Everglades 50 Mile Ultra Run (USA)
# ...                ...         ...                                 ...
# 6417091           2015  21.02.2015  Everglades 50 Mile Ultra Run (USA)
# 6417092           2015  21.02.2015  Everglades 50 Mile Ultra Run (USA)
# 6417093           2015  21.02.2015  Everglades 50 Mile Ultra Run (USA)
# 6417094           2015  21.02.2015  Everglades 50 Mile Ultra Run (USA)
# 6417095           2015  21.02.2015  Everglades 50 Mile Ultra Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
df[df['Event name'] == 'Everglades 50 Mile Ultra Run (USA)'] ['Event name'].str.split('(')
# Out:
# 51923      [Everglades 50 Mile Ultra Run , USA)]
# 51924      [Everglades 50 Mile Ultra Run , USA)]
# 51925      [Everglades 50 Mile Ultra Run , USA)]
# 51926      [Everglades 50 Mile Ultra Run , USA)]
# 51927      [Everglades 50 Mile Ultra Run , USA)]
#                            ...
# 6417091    [Everglades 50 Mile Ultra Run , USA)]
# 6417092    [Everglades 50 Mile Ultra Run , USA)]
# 6417093    [Everglades 50 Mile Ultra Run , USA)]
# 6417094    [Everglades 50 Mile Ultra Run , USA)]
# 6417095    [Everglades 50 Mile Ultra Run , USA)]
# Name: Event name, Length: 338, dtype: object

# %%
df[df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0)  == 'USA' ]
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event']==2020) & (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0)  == 'USA')]
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
# ...                ...         ...
# 2760957           2020  03.10.2020
# 2760958           2020  03.10.2020
# 2760959           2020  03.10.2020
# 2760960           2020  03.10.2020
# 2760961           2020  03.10.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
# ...

# %%
df2= df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event']==2020) & (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0)  == 'USA')]

# %%
df2.head(10)
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
# 2539950           2020  02.02.2020
# 2539951           2020  02.02.2020
# 2539952           2020  02.02.2020
# 2539953           2020  02.02.2020
# 2539954           2020  02.02.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539950  West Seattle Beach Run - Winter Edition (USA)                  50km
# ...

# %%
df2.shape
# Out:
# (26090, 13)

# %%
# removing (USA) from event name

# %%
df2['Event name'].str.split('(').str.get(0)
# Out:
# 2539945    West Seattle Beach Run - Winter Edition
# 2539946    West Seattle Beach Run - Winter Edition
# 2539947    West Seattle Beach Run - Winter Edition
# 2539948    West Seattle Beach Run - Winter Edition
# 2539949    West Seattle Beach Run - Winter Edition
#                              ...
# 2760957     Yankee Springs Fall Trail Run Festival
# 2760958     Yankee Springs Fall Trail Run Festival
# 2760959     Yankee Springs Fall Trail Run Festival
# 2760960     Yankee Springs Fall Trail Run Festival
# 2760961     Yankee Springs Fall Trail Run Festival
# Name: Event name, Length: 26090, dtype: object

# %%
# cleaning data (athlete age)

# %%
df2['athlete_age']= 2020 - df2['Athlete year of birth']
# Out:
# /var/folders/rc/tjd3sybx64z78y7cpl6g_7kh0000gn/T/ipykernel_45851/1024392250.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['athlete_age']= 2020 - df2['Athlete year of birth']

# %%
# removing h from athlete performance

# %%
df2['Athlete performance'].str.split(' ').str.get(0)
# Out:
# 2539945    3:17:55
# 2539946    4:02:32
# 2539947    4:07:57
# 2539948    4:22:02
# 2539949    4:27:34
#             ...
# 2760957    7:07:48
# 2760958    7:27:22
# 2760959    7:27:24
# 2760960    7:38:30
# 2760961    7:59:53
# Name: Athlete performance, Length: 26090, dtype: object

# %%
df2['Athlete performance']= df2['Athlete performance'].str.split(' ').str.get(0)
# Out:
# /var/folders/rc/tjd3sybx64z78y7cpl6g_7kh0000gn/T/ipykernel_45851/1247256461.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete performance']= df2['Athlete performance'].str.split(' ').str.get(0)

# %%
df2.head(5)
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
#
#          Event number of finishers Athlete performance  \
# 2539945                         20             3:17:55
# 2539946                         20             4:02:32
# 2539947                         20             4:07:57
# 2539948                         20             4:22:02
# ...

# %%
# dropping columns

# %%
df2 = df2.drop(['Athlete club','Athlete country'], axis = 1)

# %%
df2.head(5)
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
#
#          Event number of finishers Athlete performance  Athlete year of birth  \
# 2539945                         20             3:17:55                 1991.0
# 2539946                         20             4:02:32                 1981.0
# ...

# %%
# cleaning up null values

# %%
df2.isna().sum()
# Out:
# Year of event                  0
# Event dates                    0
# Event name                     0
# Event distance/length          0
# Event number of finishers      0
# Athlete performance            0
# Athlete year of birth        233
# Athlete gender                 0
# Athlete age category         217
# Athlete average speed          0
# Athlete ID                     0
# athlete_age                  233
# dtype: int64

# %%
df2[df2['athlete_age'].isna()==1]
# Out:
#          Year of event Event dates                                Event name  \
# 2547794           2020  25.01.2020        North Carolina Fat Ass 50 Km (USA)
# 2551331           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K (USA)
# 2551336           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K (USA)
# 2551344           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K (USA)
# 2551348           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K (USA)
# ...                ...         ...                                       ...
# 2746543           2020  17.10.2020     Black River Trail Classic 50 Km (USA)
# 2749869           2020  17.10.2020  MuleSkinner Endurance 50 Mile Race (USA)
# 2755985           2020  10.10.2020      Man Against Horse 50 Mile Race (USA)
# 2755994           2020  10.10.2020      Man Against Horse 50 Mile Race (USA)
# 2755997           2020  10.10.2020      Man Against Horse 50 Mile Race (USA)
#
# ...

# %%
df2 = df2.dropna()

# %%
df2.shape
# Out:
# (25857, 12)

# %%
#check for dupes

# %%
df2[df2.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete year of birth, Athlete gender, Athlete age category, Athlete average speed, Athlete ID, athlete_age]
# Index: []

# %%
df2.reset_index(drop = True)       # reset index
# Out:
#        Year of event Event dates  \
# 0               2020  02.02.2020
# 1               2020  02.02.2020
# 2               2020  02.02.2020
# 3               2020  02.02.2020
# 4               2020  02.02.2020
# ...              ...         ...
# 25852           2020  03.10.2020
# 25853           2020  03.10.2020
# 25854           2020  03.10.2020
# 25855           2020  03.10.2020
# 25856           2020  03.10.2020
#
#                                           Event name Event distance/length  \
# 0      West Seattle Beach Run - Winter Edition (USA)                  50km
# 1      West Seattle Beach Run - Winter Edition (USA)                  50km
# 2      West Seattle Beach Run - Winter Edition (USA)                  50km
# 3      West Seattle Beach Run - Winter Edition (USA)                  50km
# 4      West Seattle Beach Run - Winter Edition (USA)                  50km
# ...                                              ...                   ...
# ...

# %%
#fix types

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# athlete_age                  float64
# dtype: object

# %%
df2['athlete_age']= df2['athlete_age'].astype(int)
# Out:
# /var/folders/rc/tjd3sybx64z78y7cpl6g_7kh0000gn/T/ipykernel_45851/130840868.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['athlete_age']= df2['athlete_age'].astype(int)

# %%
df2['Athlete average speed']= df2['Athlete average speed'].astype(float)
# Out:
# /var/folders/rc/tjd3sybx64z78y7cpl6g_7kh0000gn/T/ipykernel_45851/1623033049.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete average speed']= df2['Athlete average speed'].astype(float)

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed        float64
# Athlete ID                     int64
# athlete_age                    int64
# dtype: object

# %%
df2=df2.rename(columns = {'year of event': 'year',
             'Event dates':'race_day',
               'Event name': 'race_ name',
              'Event distance/length':'race_length',
              'Event number of finishers':'race no. of finisher'
              })

# %%
df2.head(3)
# Out:
#          Year of event    race_day  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
#
#                                             race_ name race_length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)        50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)        50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)        50km
#
#          race no. of finisher Athlete performance  Athlete year of birth  \
# 2539945                    20             3:17:55                 1991.0
# 2539946                    20             4:02:32                 1981.0
# 2539947                    20             4:07:57                 1999.0
#
#         Athlete gender Athlete age category  Athlete average speed  \
# 2539945              M                  M23                 15.158
# 2539946              M                  M35                 12.369
# ...

# %%
df3=df2[['race_day','race_ name','race_length','race no. of finisher','Athlete performance','Athlete year of birth','Athlete gender','Athlete age category','Athlete average speed','Athlete ID','athlete_age']]

# %%
df3.head(10)
# Out:
#            race_day                                     race_ name  \
# 2539945  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539946  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539947  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539948  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539949  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539950  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539951  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539952  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539953  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539954  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
#
#         race_length  race no. of finisher Athlete performance  \
# 2539945        50km                    20             3:17:55
# 2539946        50km                    20             4:02:32
# ...

# %%
#find race that was ran in 2020 - sarasotas/Everglades

# %%
df3[df3['race_ name'] == 'Everglades 50 Mile Ultra Run (USA)' ]
# Out:
#            race_day                          race_ name race_length  \
# 2591476  14.03.2020  Everglades 50 Mile Ultra Run (USA)        50mi
# 2591477  14.03.2020  Everglades 50 Mile Ultra Run (USA)        50mi
# 2591478  14.03.2020  Everglades 50 Mile Ultra Run (USA)        50mi
# 2591479  14.03.2020  Everglades 50 Mile Ultra Run (USA)        50mi
# 2591480  14.03.2020  Everglades 50 Mile Ultra Run (USA)        50mi
# 2591481  14.03.2020  Everglades 50 Mile Ultra Run (USA)        50mi
# 2591482  14.03.2020  Everglades 50 Mile Ultra Run (USA)        50mi
# 2591483  14.03.2020  Everglades 50 Mile Ultra Run (USA)        50mi
# 2591484  14.03.2020  Everglades 50 Mile Ultra Run (USA)        50mi
# 2591485  14.03.2020  Everglades 50 Mile Ultra Run (USA)        50mi
# 2591486  14.03.2020  Everglades 50 Mile Ultra Run (USA)        50mi
# 2591487  14.03.2020  Everglades 50 Mile Ultra Run (USA)        50mi
# 2591488  14.03.2020  Everglades 50 Mile Ultra Run (USA)        50mi
# ...

# %%
df3[df3['Athlete ID'] == 696060]
# Out:
#            race_day                          race_ name race_length  \
# 2591495  14.03.2020  Everglades 50 Mile Ultra Run (USA)        50mi
# 2694727  27.12.2020   Jupiter Ridge Sand Spur 50k (USA)        50km
#
#          race no. of finisher Athlete performance  Athlete year of birth  \
# 2591495                    40            11:09:54                 1990.0
# 2694727                    27             7:06:36                 1990.0
#
#         Athlete gender Athlete age category  Athlete average speed  \
# 2591495              M                  M23                  7.207
# 2694727              M                  M23                  7.032
#
#          Athlete ID  athlete_age
# 2591495      696060           30
# 2694727      696060           30

# %%
# VISUALIZATIONS

# %%
sns.histplot(df3['race_length'])
# Out:
# <AxesSubplot:xlabel='race_length', ylabel='Count'>

# %%
sns.histplot(df3,x = 'race_length', hue = 'Athlete gender')
# Out:
# <AxesSubplot:xlabel='race_length', ylabel='Count'>

# %%
sns.displot(df3[df3['race_length'] == '50mi']['Athlete average speed'])

# %%
sns.violinplot(data =df3, x= 'race_length',y= 'Athlete average speed', hue = 'Athlete gender')
# Out:
# <AxesSubplot:xlabel='race_length', ylabel='Athlete average speed'>

# %%
sns.lmplot(data =df3, x= 'athlete_age',y= 'Athlete average speed')

# %%
sns.lmplot(data =df3, x= 'athlete_age',y= 'Athlete average speed', hue ='Athlete gender')

# %%
# difference in 50k ,50 mi ,(male to female )

# %%
df3.groupby(['race_length','Athlete gender'])['Athlete average speed'].mean()
# Out:
# race_length  Athlete gender
# 50km         F                 7.083011
#              M                 7.738985
# 50mi         F                 6.834371
#              M                 7.257633
# Name: Athlete average speed, dtype: float64

# %%
# age groups best in 50m race

# %%
df3.query('race_length == "50mi"').groupby('athlete_age')['Athlete average speed'].agg(['mean','count']).sort_values('mean', ascending= False).query('count>19')
# Out:
#                  mean  count
# athlete_age
# 29           7.902252    135
# 23           7.779800     55
# 28           7.575252    107
# 30           7.569204    157
# 25           7.540923     91
# 31           7.451638    138
# 38           7.430022    231
# 35           7.422359    195
# 36           7.403854    185
# 26           7.379800     75
# 33           7.379188    149
# 22           7.367902     41
# 24           7.354274     73
# 42           7.327656    209
# 34           7.319011    182
# 40           7.310669    236
# 21           7.304658     38
# 20           7.293778     27
# 32           7.287969    162
# 39           7.283648    227
# 37           7.220493    221
# 27           7.201748    119
# 41           7.197017    179
# 45           7.130667    156
# 47           7.085410    156
# 44           7.052642    179
# 51           7.019379    124
# 46           6.897236    174
# 43           6.884225    187
# 52           6.847400    130
# ...
